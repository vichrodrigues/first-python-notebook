# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 062- DEATH PENALTY. INITIATIVE STATUTE.                                                                                                             7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 6   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# ...

# %%
props.loc[props['prop_name'] == 'PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH REQUIREMENTS. INITIATIVE STATUTE.' ]
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 58  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 59  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#     ccdc_prop_id                                          prop_name  \
# 58            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 59            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 58                440                 1356566
# 59                441                 1385139
#
#                                        committee_name committee_position
# 58  YES ON PROP 60, FOR ADULT INDUSTRY RESPONSIBIL...            SUPPORT
# 59  NO ON PROPOSITION 60, CALIFORNIANS AGAINST WOR...             OPPOSE

# %%
props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 72     False
# 73     False
# 74      True
# 75      True
# 76      True
# 77      True
# 78      True
# 79      True
# 80      True
# 81      True
# 82      True
# 83      True
# 84      True
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# Name: prop_name, dtype: bool

# %%
props[props.prop_name == 'PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 74  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 75  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 76  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 77  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 78  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 79  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 80  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 81  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 82  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 83  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
# 84  ocd-contest/232cb72c-1b11-4293-b4e2-a181e80d172e            1381868
#
#     ccdc_prop_id                                          prop_name  \
# ...

# %%
prop = props[props.prop_name == 'PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH REQUIREMENTS. INITIATIVE STATUTE.']

# %%
prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 58  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 59  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#     ccdc_prop_id                                          prop_name  \
# 58            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 59            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 58                440                 1356566
# 59                441                 1385139
#
#                                        committee_name committee_position
# 58  YES ON PROP 60, FOR ADULT INDUSTRY RESPONSIBIL...            SUPPORT
# 59  NO ON PROPOSITION 60, CALIFORNIANS AGAINST WOR...             OPPOSE

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2 entries, 58 to 59
# Data columns (total 8 columns):
# ocd_prop_id               2 non-null object
# calaccess_prop_id         2 non-null int64
# ccdc_prop_id              2 non-null int64
# prop_name                 2 non-null object
# ccdc_committee_id         2 non-null int64
# calaccess_committee_id    2 non-null int64
# committee_name            2 non-null object
# committee_position        2 non-null object
# dtypes: int64(4), object(4)
# memory usage: 112.0+ bytes

# %%
props.query("ccdc_prop_id == 79")
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 58  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 59  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#     ccdc_prop_id                                          prop_name  \
# 58            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 59            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 58                440                 1356566
# 59                441                 1385139
#
#                                        committee_name committee_position
# 58  YES ON PROP 60, FOR ADULT INDUSTRY RESPONSIBIL...            SUPPORT
# 59  NO ON PROPOSITION 60, CALIFORNIANS AGAINST WOR...             OPPOSE

# %%
yes60 = contribs.query('calaccess_committee_id == 1356566')

# %%
yes60.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 54750 to 54770
# Data columns (total 13 columns):
# calaccess_committee_id          21 non-null int64
# committee_name                  21 non-null object
# calaccess_filing_id             21 non-null int64
# date_received                   21 non-null object
# contributor_lastname            21 non-null object
# contributor_firstname           0 non-null object
# contributor_city                21 non-null object
# contributor_state               21 non-null object
# contributor_zip                 21 non-null object
# contributor_employer            0 non-null object
# contributor_occupation          0 non-null object
# contributor_is_self_employed    21 non-null bool
# amount                          21 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 1.4+ KB

# %%
yes60.contributor_lastname.unique()
# Out:
# array(['AIDS HEALTHCARE FOUNDATION'], dtype=object)

# %%
no60 = contribs.query('calaccess_committee_id == 1385139')

# %% [markdown]
# no60.contributor_lastname.unique()

# %%
no60.contributor_lastname.unique()
# Out:
# array(['AEBN', 'CYBERNET ENTERTAINMENT', 'E.A. PRODUCTIONS',
#        'HARD DRIVE PRODUCTIONS  INC.', 'TROPICAL MBC  LLC',
#        'VIVID ENTERTAINMENT', 'WICKED PICTURES',
#        'WICKED SENSUAL CARE  INC.', 'DIME SYSTEMS  LLC', 'KAMINSKY', 'LEE',
#        'BEBAN', 'CALEXOTICS', 'CASAUS', 'COFFMAN', 'DOUGLAS', 'EAMES',
#        'ELINE LP', 'SARJ  LLC',
#        'EROTIC SERVICE PROVIDER LEGAL EDUCATION AND RESEARCH PROJECT (ESPLERP)',
#        'FINQUEL', 'GALLON', 'GARLAND', 'HAMEL', 'HARVEY',
#        'JEFFREY GREENBERG AND AFFILIATED ENTITIES (GLOBAL PERSONALS  WORLDWIDE CONNECT  WEALTHYMEN.COM)',
#        'JOHN STAGLIANO AND AFFILIATED ENTITIES (INCLUDING E.A. PRODUCTIONS AND ZOZO PRODUCTIONS)',
#        'LICENSED ADULT TALENT AGENTS TRADE ASSOCIATION', 'MANZO',
#        'MULTIMEDIA LLC', 'PENTHOUSE GLOBAL MEDIA  INC.', 'PHE  INC.',
#        'PREVITIRE', 'PRO DATA TECH  LLC', 'ROCKET305  LLC',
#        'SCOTT TAYLOR AND AFFILIATED ENTITIES', 'SWIMMER', 'TAVELLA',
# ...

# %%
len(no60.contributor_lastname.unique())
# Out:
# 80

# %%
len(yes60.contributor_lastname.unique())
# Out:
# 1

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 4.8+ KB

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
merged = pd.merge(prop, contribs, on='calaccess_committee_id')

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 1  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 2  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 3  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 4  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#    ccdc_prop_id                                          prop_name  \
# 0            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 1            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 2            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 3            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 4            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                440                 1356566
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 0 to 114
# Data columns (total 20 columns):
# ocd_prop_id                     115 non-null object
# calaccess_prop_id               115 non-null int64
# ccdc_prop_id                    115 non-null int64
# prop_name                       115 non-null object
# ccdc_committee_id               115 non-null int64
# calaccess_committee_id          115 non-null int64
# committee_name_x                115 non-null object
# committee_position              115 non-null object
# committee_name_y                115 non-null object
# calaccess_filing_id             115 non-null int64
# date_received                   115 non-null object
# contributor_lastname            115 non-null object
# contributor_firstname           56 non-null object
# contributor_city                115 non-null object
# contributor_state               115 non-null object
# contributor_zip                 115 non-null object
# ...

# %%
merged.amount
# Out:
# 0       200000.00
# 1       150000.00
# 2       100000.00
# 3       150000.00
# 4       100000.00
# 5       150000.00
# 6       200000.00
# 7       150000.00
# 8       150000.00
# 9       100000.00
# 10       20000.00
# 11       60000.00
# 12      100000.00
# 13      150000.00
# 14       50000.00
# 15       25000.00
# 16     1000000.00
# 17      900000.00
# 18      800000.00
# 19       50000.00
# 20       50000.00
# 21        4024.40
# 22        8048.79
# 23        8048.79
# 24        1609.75
# 25        3219.50
# 26        4024.38
# 27       44000.00
# 28        4024.39
# 29       10000.00
#           ...
# 85        1000.00
# 86         250.00
# 87        3000.00
# 88         100.00
# 89        1000.00
# 90         500.00
# 91        5000.00
# 92        2000.00
# 93         100.00
# 94         100.00
# 95         100.00
# 96         500.00
# 97        1000.00
# 98        5000.00
# 99         100.00
# 100       9995.00
# 101      10000.00
# 102      10000.00
# 103       5000.00
# ...

# %%
merged.amount.sum()
# Out:
# 5032221.0

# %%
merged.committee_position.value_counts()
# Out:
# OPPOSE     94
# SUPPORT    21
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == 'SUPPORT']

# %%
oppose = merged[merged.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()
# Out:
# 377221.0

# %%
support.amount.sum()
# Out:
# 4655000.0

# %%
support.amount.sum()/merged.amount.sum()
# Out:
# 0.9250388645490729

# %%
merged.sort_values('amount')
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 48   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 110  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 46   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 64   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 57   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 78   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 58   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 53   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 88   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 47   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 74   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 45   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# ...

# %%
merged.sort_values('amount', ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 16   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 17   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 18   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 0    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 6    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 8    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 13   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 1    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 7    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 5    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 3    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 9    ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# ...

# %%
support.sort_values('amount', ascending=False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 16  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 17  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 18  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 6   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 0   ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#     ccdc_prop_id                                          prop_name  \
# 16            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 17            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 18            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 6             79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 0             79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 16                440                 1356566
# ...

# %%
oppose.sort_values('amount', ascending=False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 27  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 50  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 51  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 54  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
# 56  ocd-contest/9cee6ef5-cd54-4423-9c29-66c7823c1c3a            1376195
#
#     ccdc_prop_id                                          prop_name  \
# 27            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 50            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 51            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 54            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
# 56            79  PROPOSITION 060- ADULT FILMS. CONDOMS. HEALTH ...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 27                441                 1385139
# ...

# %%
merged.groupby('committee_name_x').amount.sum().reset_index().sort_values('amount',ascending=False)
# Out:
#                                     committee_name_x     amount
# 1  YES ON PROP 60, FOR ADULT INDUSTRY RESPONSIBIL...  4655000.0
# 0  NO ON PROPOSITION 60, CALIFORNIANS AGAINST WOR...   377221.0

# %%
merged.groupby(['contributor_firstname','contributor_lastname']).amount.sum().reset_index().sort_values('amount',ascending=False)
# Out:
#    contributor_firstname contributor_lastname  amount
# 24                  MARK             SPIEGLER  9995.0
# 31                  PHIL               HARVEY  9000.0
# 37                 SCOTT               TAYLOR  5000.0
# 8                  FRANK             KORETSKY  5000.0
# 11                  GREG                ALVES  5000.0
# 5                  CHRIS                GRACE  3000.0
# 26               MICHAEL               WARNER  2500.0
# 45               WILLIAM              DELLARA  2000.0
# 20                 KAREN                TYNAN  2000.0
# 40                STEVEN               GALLON  1500.0
# 16               JEFFREY              DOUGLAS  1000.0
# 42              TERRENCE                 BELL  1000.0
# 34                ROBERT                BEBAN  1000.0
# 32                RACHEL              SWIMMER  1000.0
# 17                  JOEL             KAMINSKY  1000.0
# 0                   ALAN                EIGEN  1000.0
# ...

# %%
merged.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                  contributor_lastname committee_position  \
# 2                          AIDS HEALTHCARE FOUNDATION            SUPPORT
# 79                                    WICKED PICTURES             OPPOSE
# 40  JEFFREY GREENBERG AND AFFILIATED ENTITIES (GLO...             OPPOSE
# 41  JOHN STAGLIANO AND AFFILIATED ENTITIES (INCLUD...             OPPOSE
# 74                                VIVID ENTERTAINMENT             OPPOSE
# 55                                     MULTIMEDIA LLC             OPPOSE
# 58                                          PHE  INC.             OPPOSE
# 17                                  DIME SYSTEMS  LLC             OPPOSE
# 66               SCOTT TAYLOR AND AFFILIATED ENTITIES             OPPOSE
# 78                            WEB DATA SOLUTIONS  LLC             OPPOSE
# 61                                 PRO DATA TECH  LLC             OPPOSE
# 67                                           SPIEGLER             OPPOSE
# ...
